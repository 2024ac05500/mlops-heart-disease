# %% [markdown]
# # Model Evaluation
# This notebook loads trained model artifacts and the processed test dataset, computes evaluation metrics (accuracy, precision, recall, F1, ROC-AUC), and plots ROC curves, Precision-Recall curves, and confusion matrices for each model. Plots are saved to the `screenshots/` folder.

# %%
import os
from pathlib import Path
import glob
import joblib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (roc_curve, auc, precision_recall_curve, confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score)

sns.set(style="whitegrid")
os.makedirs('screenshots', exist_ok=True)
: 
,
: {
: 
},
: [
,
,
,
,
,
,
,

: 
,
: {
: 
},
: [
,
,
# Out:
#   Cell In[1], line 13
#     :
#     ^
# SyntaxError: invalid syntax
